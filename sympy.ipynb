# %% [markdown]
# ### Мы будем использовать библиотеку SymPy и хотим красиво печатать математические формулы

# %%
from sympy import *

# %% [markdown]
# ### Вот это — просто Python

# %% [markdown]
# Просто 3 в сотой степени:

# %%
3**100
# Out:
# 515377520732011331036461129765621272702107522001

# %% [markdown]
# Здесь и комментировать нечего:

# %%
1 + 1 + 1 == 3
# Out:
# True

# %% [markdown]
# Понимаете, почему так?

# %%
0.1 + 0.1 + 0.1 == 0.3
# Out:
# False

# %% [markdown]
# А это понятно?

# %%
1/2 + 1/3
# Out:
# 0.8333333333333333

# %% [markdown]
# Пример простенького цикла:

# %% [markdown]
# ### Теперь воспользуемся возможностями библиотеки SymPy

# %% [markdown]
# Точные вычисления с простыми дробями (рациональными числами):

# %%
Rational(1, 2)
# Out:
# 1/2

# %%
Rational(1, 2) + Rational(1, 3)
# Out:
# 5/6

# %% [markdown]
# Преобразование арифметических выражений:

# %% [markdown]
# ### Интересная задача

# %% [markdown]
# Найдите такие целые положительные числа $a$, $b$ и $c$, чтобы выполнялось равенство
# $$\frac{a}{b+c} + \frac{b}{a+c} + \frac{c}{a+b} = 4.$$

# %% [markdown]
# Оказывается, что минимальные числа, удовлетворяющие этому соотношению таковы:

# %%
var('a b c')
a=154476802108746166441951315019919837485664325669565431700026634898253202035277999
b=36875131794129999827197811565225474825492979968971970996283137471637224634055579  
c=4373612677928697257861252602371390152816537558161613618621437993378423467772036
Rational(a,b+c) + Rational(b,a+c) + Rational(c,a+b)
# Out:
# 4

# %% [markdown]
# Вот команды, иллюстрирующие некоторые возможности библиотеки SymPy:

# %%
var('x y z')
expand((x+y-2*z)**2)
# Out:
#  2                    2              2
# x  + 2⋅x⋅y - 4⋅x⋅z + y  - 4⋅y⋅z + 4⋅z

# %%
solve(x**2-x-1,x)
# Out:
# ⎡1   √5  1   √5⎤
# ⎢─ - ──, ─ + ──⎥
# ⎣2   2   2   2 ⎦

# %%
diff(x*sin(x),x)
# Out:
# x⋅cos(x) + sin(x)

# %%
integrate(x-1,x)
# Out:
#  2
# x
# ── - x
# 2

# %%
plotting.plot3d(x**2+y**2, (x,-3,3), (y,-3,3))
