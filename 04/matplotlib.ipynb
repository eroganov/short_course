# %% [markdown]
# ## Первый график

# %%
import matplotlib.pyplot as plt
plt.plot([-1, -4.5, 16, 23])
plt.show()

# %% [markdown]
# ## График функции

# %%
import numpy as np
X = np.linspace(0, 2 * np.pi, 50, endpoint=True)
F = np.sin(X)
plt.plot(X,F)
startx, endx = -0.1, 2*np.pi + 0.1
starty, endy = -1.1, 1.1
plt.axis([startx, endx, starty, endy])
plt.show()

# %% [markdown]
# ## Несколько графиков (разные стили)

# %%
X = np.linspace(0, 2 * np.pi, 50, endpoint=True)
F1 = 3 * np.sin(X)
F2 = np.sin(2*X)
F3 = 0.3 * np.sin(X)
F4 = np.cos(X)
plt.plot(X, F1, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, F2, color="red", linewidth=1.5, linestyle="--")
plt.plot(X, F3, color="green", linewidth=2, linestyle=":")
plt.plot(X, F4, color="grey", linewidth=2, linestyle="-.")
plt.show()

# %% [markdown]
# ## Управление параметрами визуализации

# %% [markdown]
# #### Без указания дополнительных параметров

# %%
X = np.linspace(-2 * np.pi, 2 * np.pi, 70, endpoint=True)
F = X * np.sin(X)
plt.plot(X, F)
plt.show()

# %% [markdown]
# #### С использованием параметров

# %%
X = np.linspace(-2 * np.pi, 2 * np.pi, 70, endpoint=True)
F = X * np.sin(X)
# Текущая область рисования
ax = plt.gca()
# Убираем верхнюю и правую границы области рисования
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
# Перемещаем нижнюю и левую границы
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))
# Подписи к делениям на осях
plt.xticks( [-6.28, -3.14, 3.14, 6.28],
        [r'$-2\pi$', r'$-\pi$', r'$+\pi$', r'$+2\pi$'])
plt.yticks([-3, -1, 0, +1, 3])
plt.plot(X, F)
plt.show()

# %% [markdown]
# ## Более интересные примеры
#
# Их можно найти по следующим ссылкам:
#
# - [https://matplotlib.org/tutorials/introductory/sample_plots.html](https://matplotlib.org/tutorials/introductory/sample_plots.html);
# - [https://www.python-course.eu/matplotlib_legends_and_annotations.php](https://www.python-course.eu/matplotlib_legends_and_annotations.php);
# - [https://www.python-course.eu/matplotlib_multiple_figures.php](https://www.python-course.eu/matplotlib_multiple_figures.php);
# - [https://www.python-course.eu/matplotlib_histograms.php](https://www.python-course.eu/matplotlib_histograms.php);
# - [https://www.python-course.eu/matplotlib_contour_plot.php](https://www.python-course.eu/matplotlib_contour_plot.php);
# - [https://matplotlib.org/gallery/index.html](https://matplotlib.org/gallery/index.html).
